# %%
import pandas as pd
from pathlib import Path

# %%
tracks = pd.read_csv(Path("tracks.csv"))
df = pd.DataFrame(tracks)

# %%
df.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
clean_df = df.dropna()

# %%
clean_df.duplicated().sum()
# Out:
# 0

# %%
tops = clean_df.sort_values(by=['popularity'], ascending=False, inplace=False)
tops.head()
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
# 93803          99       242014         1
# 93804          98       132780         0
# 92811          97       160191         0
# 92810          97       215627         1
#
#                                             artists  \
# 93802  ['Justin Bieber', 'Daniel Caesar', 'Giveon']
# 93803                            ['Olivia Rodrigo']
# 93804                               ['Masked Wolf']
# 92811                                ['Kali Uchis']
# ...

# %%
three_th = tops[0:3000]
tracks_df = pd.DataFrame(three_th)
tracks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3000 entries, 93802 to 93850
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                3000 non-null   object
#  1   name              3000 non-null   object
#  2   popularity        3000 non-null   int64
#  3   duration_ms       3000 non-null   int64
#  4   explicit          3000 non-null   int64
#  5   artists           3000 non-null   object
#  6   id_artists        3000 non-null   object
#  7   release_date      3000 non-null   object
#  8   danceability      3000 non-null   float64
#  9   energy            3000 non-null   float64
#  10  key               3000 non-null   int64
#  11  loudness          3000 non-null   float64
#  12  mode              3000 non-null   int64
#  13  speechiness       3000 non-null   float64
#  14  acousticness      3000 non-null   float64
#  15  instrumentalness  3000 non-null   float64
# ...

# %%
tracks_df['release_date'] = pd.to_datetime(tracks_df['release_date'], format="%Y/%m/%d")

# %%
tracks_df.set_index('release_date', inplace=True)

# %%
tracks_df.head()
# Out:
#                                   id                                    name  \
# release_date
# 2021-03-19    4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 2021-01-08    7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 2021-01-06    3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 2020-12-04    6tDDoYIxWvMLTdKpjFkc1B                               telepatía
# 2020-03-20    5QO79kh1waicV47BqGRL3g                         Save Your Tears
#
#               popularity  duration_ms  explicit  \
# release_date
# 2021-03-19           100       198082         1
# 2021-01-08            99       242014         1
# 2021-01-06            98       132780         0
# 2020-12-04            97       160191         0
# 2020-03-20            97       215627         1
#
#                                                    artists  \
# release_date
# 2021-03-19    ['Justin Bieber', 'Daniel Caesar', 'Giveon']
# ...

# %%
tracks_df['duration_s'] = round(tracks_df['duration_ms']/1000)

# %%
track_clean = tracks_df.drop(columns='duration_ms')

# %%
track_clean['artists'] = track_clean['artists'].str.replace(r'[][]', '', regex=True)
track_clean['id_artists'] = track_clean['id_artists'].str.replace(r'[][]', '', regex=True)

# %%
track_clean.sample(20)
# Out:
#                                   id  \
# release_date
# 2016-08-20    34xTFwjPQ1dC6uJmleno7x
# 2018-01-26    4wFjTWCunQFKtukqrNijEt
# 2013-07-23    3QHMxEOAGD51PDlbFPHLyJ
# 1986-01-01    3MrRksHupTVEQ7YbA0FsZK
# 2015-06-02    31c1V9xUONZYk78NE4Id8D
# 2018-09-14    0YammaEkYSeo9vQYZ1OwS6
# 2021-01-08    0mKnuxVkPi5h0kuvZl44VM
# 2018-12-10    1fCeXjoRExPP2qwSBh2aST
# 2018-06-15    4lQsB3ERTWSNaAN1IkuNRl
# 2020-10-27    6FfLg6FFqhCsrFOaHIGkg0
# 2009-08-18    4E5P1XyAFtrjpiIxkydly4
# 2017-12-22    1RGasjWLZ4qMN7wbtkLa3u
# 2018-10-26    1VGzxJnVQND7Cg5H5wGj14
# 2017-04-28    10GJQkjRJcZhGTLagFOC62
# 2017-09-29    7gvd8xj4QgPqbQSsn5pV7d
# 2020-09-10    0eoMMLrWtXbLk64baeESkc
# 2021-03-12    36CiGk9oRdwTnBDMgKEfjl
# 2004-09-27    7uKcScNXuO3MWw6LowBjW1
# 2014-07-04    4VrWlk8IQxevMvERoX08iC
# 2020-06-20    5EzL7hGT9g2Tvqsy158Lu9
#
#                                                       name  popularity  \
# release_date
# ...

# %%
track_clean.to_csv("tracks_cleaned.csv", index=False)
