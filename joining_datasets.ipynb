# %%
import pandas as pd
from pathlib import Path

# %%
tracks = pd.read_csv(Path("./clean_tracks.csv"))
tracks2 = pd.read_csv(Path("./top3000_cleaned.csv"))

# %%
tracks_df1 = pd.DataFrame(tracks)
tracks_df2 = pd.DataFrame(tracks2)
# Out:
#       artist_name                track_id  \
# 0    Daddy Yankee  5w9c2J52mkdntKOmRLeM2m
# 1     Post Malone  6MWtB6iiXyIwun0YzU6DFP
# 2   Billie Eilish  2Fxmhks0bxGSBdJ92vM42m
# 3     Post Malone  3KkXRkHbMCARz0aVfEt68P
# 4  Jonas Brothers  4y3OI86AEP6PQoDE6olYhO
#
#                                       track_name  acousticness  danceability  \
# 0                                      Con Calma        0.1100         0.737
# 1                                           Wow.        0.1630         0.833
# 2                                        bad guy        0.3080         0.708
# 3  Sunflower - Spider-Man: Into the Spider-Verse        0.5200         0.744
# 4                                         Sucker        0.0427         0.842
#
#    energy  instrumentalness  key  liveness  loudness  mode  speechiness  \
# 0   0.860          0.000002    8    0.0574    -2.652     0       0.0593
# 1   0.539          0.000002   11    0.1010    -7.399     0       0.1780
# 2   0.418          0.093000    0    0.1000   -10.998     1       0.3680
# 3   0.494          0.000000    2    0.0716    -5.563     1       0.0699
# 4   0.734          0.000000    1    0.1060    -5.065     0       0.0588
#
#      tempo  time_signature  valence  popularity  duration
# 0   93.989               4    0.656         100     193.0
# 1   99.947               4    0.385          98     150.0
# 2  131.926               4    0.578          98     194.0
# 3   89.972               4    0.927          98     158.0
# 4  137.958               4    0.952          98     181.0

# %%
df1 = tracks_df1.drop(columns='release_date')
df_sort = df1.sort_values('popularity', ascending=False)
df_sort.reset_index(drop=True)
df_sort.head()
# Out:
#                           artist_name                track_id  \
# 0  Justin Bieber Daniel Caesar Giveon  4iJyoBOLtHqaGxP12qzhQI
# 1                      Olivia Rodrigo  7lPN2DXiMsVn7XUKtOW1CS
# 2                         Masked Wolf  3Ofmpyhv5UAQ70mENzB277
# 3                          Kali Uchis  6tDDoYIxWvMLTdKpjFkc1B
# 4                          The Weeknd  5QO79kh1waicV47BqGRL3g
#
#                                track_name  acousticness  danceability  energy  \
# 0  Peaches (feat. Daniel Caesar & Giveon)        0.3210         0.677   0.696
# 1                         drivers license        0.7210         0.585   0.436
# 2                  Astronaut In The Ocean        0.1750         0.778   0.695
# 3                               telepatía        0.1120         0.653   0.524
# 4                         Save Your Tears        0.0212         0.680   0.826
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000000    0     0.420    -6.181     1       0.1190   90.030
# 1          0.000013   10     0.105    -8.761     1       0.0601  143.874
# 2          0.000000    4     0.150    -6.865     0       0.0913  149.996
# 3          0.000000   11     0.203    -9.016     0       0.0502   83.970
# 4          0.000012    0     0.543    -5.487     1       0.0309  118.051
#
#    time_signature  valence  popularity  duration
# 0               4    0.464         100     198.0
# 1               4    0.132          99     242.0
# 2               4    0.472          98     133.0
# 3               4    0.553          97     160.0
# 4               4    0.644          97     216.0

# %%
df_sort1 = tracks_df2.sort_values('popularity', ascending=False)

# %%
df2 = df_sort1.reset_index(drop=True)

# %%
frames = [df_sort, df2]

# %%
df_main = pd.concat(frames)

# %%
df_main.duplicated().sum()
# Out:
# 2

# %%
df_clean = df.drop_duplicates()

# %%
df_clean1 = df_clean.drop_duplicates(subset=['track_id'])
df_clean2 = df_clean.drop_duplicates(subset=['track_name'])

# %%
df_clean1.reset_index(drop=True)
# Out:
#                              artist_name                track_id  \
# 0     Justin Bieber Daniel Caesar Giveon  4iJyoBOLtHqaGxP12qzhQI
# 1                         Olivia Rodrigo  7lPN2DXiMsVn7XUKtOW1CS
# 2                            Masked Wolf  3Ofmpyhv5UAQ70mENzB277
# 3                             Kali Uchis  6tDDoYIxWvMLTdKpjFkc1B
# 4                             The Weeknd  5QO79kh1waicV47BqGRL3g
# ...                                  ...                     ...
# 5713                         Hugo Helmig  0kTUf60V9AQTqNVKZAmJKc
# 5714                       Adriel Favela  1jyj2mL9cplsZwXrtJCEFm
# 5715                             Greeicy  7HCZWKJmHITV7Pt5YTQDcL
# 5716                              Future  2vs5ubqg8QUbfyWZpMfvWe
# 5717                        Rockie Fresh  4m6WLZKQduuQLd9wvQjOZl
#
#                                   track_name  acousticness  danceability  \
# 0     Peaches (feat. Daniel Caesar & Giveon)        0.3210         0.677
# 1                            drivers license        0.7210         0.585
# 2                     Astronaut In The Ocean        0.1750         0.778
# 3                                  telepatía        0.1120         0.653
# 4                            Save Your Tears        0.0212         0.680
# ...                                      ...           ...           ...
# 5713                                    Wild        0.0178         0.693
# 5714                   No Te Ilusiones Tanto        0.6760         0.761
# 5715                             Ya Para Qué        0.9360         0.616
# 5716                              Astronauts        0.0402         0.732
# 5717                                 Must Be        0.3860         0.709
#
#       energy  instrumentalness  key  liveness  loudness  mode  speechiness  \
# 0      0.696          0.000000    0    0.4200    -6.181     1       0.1190
# 1      0.436          0.000013   10    0.1050    -8.761     1       0.0601
# 2      0.695          0.000000    4    0.1500    -6.865     0       0.0913
# 3      0.524          0.000000   11    0.2030    -9.016     0       0.0502
# 4      0.826          0.000012    0    0.5430    -5.487     1       0.0309
# ...      ...               ...  ...       ...       ...   ...          ...
# 5713   0.720          0.000014    1    0.0544    -5.661     1       0.0362
# 5714   0.501          0.000000    5    0.0771    -5.190     1       0.0394
# 5715   0.267          0.000001    0    0.1800    -9.333     1       0.1260
# 5716   0.586          0.000003    1    0.1210    -7.868     1       0.2320
# 5717   0.770          0.000000    2    0.1210    -4.216     1       0.1580
#
#         tempo  time_signature  valence  popularity  duration
# 0      90.030               4    0.464         100     198.0
# 1     143.874               4    0.132          99     242.0
# 2     149.996               4    0.472          98     133.0
# 3      83.970               4    0.553          97     160.0
# 4     118.051               4    0.644          97     216.0
# ...       ...             ...      ...         ...       ...
# 5713   94.995               4    0.767          67     211.0
# 5714  147.943               3    0.967          67     203.0
# 5715  173.261               4    0.598          67     207.0
# 5716   76.480               4    0.730          67     170.0
# 5717  138.939               4    0.463          67     162.0
#
# [5718 rows x 17 columns]

# %%
df_clean1.to_csv('second_dataset.csv', index=False)
