# %%
import pandas as pd
import os
from pathlib import Path

# %%
# Read the Spotify data file and store it in a pandas DataFrame
spotify_data = Path('./SpotifySongPop.csv')
spotify_df = pd.read_csv(spotify_data)

# %%
spotify_df.head()
# Out:
#   artist_name                track_id  \
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1          YG  1tHDG53xJNGsItRA3vfVgs
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
#
#                                        track_name  acousticness  danceability  \
# 0  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820         0.743
# 1                    BAND DRUM (feat. A$AP Rocky)      0.024400         0.846
# 2                                   Radio Silence      0.025000         0.603
# 3                                         Lactose      0.029400         0.800
# 4                             Same - Original mix      0.000035         0.783
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       238373   0.339             0.000    1    0.0812    -7.678     1
# 1       214800   0.557             0.000    8    0.2860    -7.259     1
# 2       138913   0.723             0.000    9    0.0824    -5.890     0
# 3       125381   0.579             0.912    5    0.0994   -12.118     0
# 4       124016   0.792             0.878    7    0.0332   -10.277     1
#
#    speechiness    tempo  time_signature  valence  popularity
# 0       0.4090  203.927               4    0.118          15
# 1       0.4570  159.009               4    0.371           0
# 2       0.0454  114.966               4    0.382          56
# 3       0.0701  123.003               4    0.641           0
# 4       0.0661  120.047               4    0.928           0

# %%
spotify_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130663 entries, 0 to 130662
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   artist_name       130663 non-null  object
#  1   track_id          130663 non-null  object
#  2   track_name        130663 non-null  object
#  3   acousticness      130663 non-null  float64
#  4   danceability      130663 non-null  float64
#  5   duration_ms       130663 non-null  int64
#  6   energy            130663 non-null  float64
#  7   instrumentalness  130663 non-null  float64
#  8   key               130663 non-null  int64
#  9   liveness          130663 non-null  float64
#  10  loudness          130663 non-null  float64
#  11  mode              130663 non-null  int64
#  12  speechiness       130663 non-null  float64
#  13  tempo             130663 non-null  float64
#  14  time_signature    130663 non-null  int64
#  15  valence           130663 non-null  float64
#  16  popularity        130663 non-null  int64
# dtypes: float64(9), int64(5), object(3)
# memory usage: 16.9+ MB

# %%
spotify_df.isnull().sum()
# Out:
# artist_name         0
# track_id            0
# track_name          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# popularity          0
# dtype: int64

# %%
cleaned_spotify_df = spotify_df.dropna()

# %%
cleaned_spotify_df.duplicated().sum()
# Out:
# 0

# %%
cleaned_spotify_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130663 entries, 0 to 130662
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   artist_name       130663 non-null  object
#  1   track_id          130663 non-null  object
#  2   track_name        130663 non-null  object
#  3   acousticness      130663 non-null  float64
#  4   danceability      130663 non-null  float64
#  5   duration_ms       130663 non-null  int64
#  6   energy            130663 non-null  float64
#  7   instrumentalness  130663 non-null  float64
#  8   key               130663 non-null  int64
#  9   liveness          130663 non-null  float64
#  10  loudness          130663 non-null  float64
#  11  mode              130663 non-null  int64
#  12  speechiness       130663 non-null  float64
#  13  tempo             130663 non-null  float64
#  14  time_signature    130663 non-null  int64
#  15  valence           130663 non-null  float64
#  16  popularity        130663 non-null  int64
# dtypes: float64(9), int64(5), object(3)
# memory usage: 16.9+ MB

# %%
cleaned_spotify_df['duration'] = round(cleaned_spotify_df['duration_ms']/1000)

# %%
cleaned_spotify_df.head()
# Out:
#   artist_name                track_id  \
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1          YG  1tHDG53xJNGsItRA3vfVgs
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
#
#                                        track_name  acousticness  danceability  \
# 0  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820         0.743
# 1                    BAND DRUM (feat. A$AP Rocky)      0.024400         0.846
# 2                                   Radio Silence      0.025000         0.603
# 3                                         Lactose      0.029400         0.800
# 4                             Same - Original mix      0.000035         0.783
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       238373   0.339             0.000    1    0.0812    -7.678     1
# 1       214800   0.557             0.000    8    0.2860    -7.259     1
# 2       138913   0.723             0.000    9    0.0824    -5.890     0
# 3       125381   0.579             0.912    5    0.0994   -12.118     0
# 4       124016   0.792             0.878    7    0.0332   -10.277     1
#
#    speechiness    tempo  time_signature  valence  popularity  duration
# 0       0.4090  203.927               4    0.118          15     238.0
# 1       0.4570  159.009               4    0.371           0     215.0
# 2       0.0454  114.966               4    0.382          56     139.0
# 3       0.0701  123.003               4    0.641           0     125.0
# 4       0.0661  120.047               4    0.928           0     124.0

# %%
clean_spotify_df = cleaned_spotify_df.drop(columns={'duration_ms'})
clean_spotify_df.head()
# Out:
#   artist_name                track_id  \
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1          YG  1tHDG53xJNGsItRA3vfVgs
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
#
#                                        track_name  acousticness  danceability  \
# 0  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820         0.743
# 1                    BAND DRUM (feat. A$AP Rocky)      0.024400         0.846
# 2                                   Radio Silence      0.025000         0.603
# 3                                         Lactose      0.029400         0.800
# 4                             Same - Original mix      0.000035         0.783
#
#    energy  instrumentalness  key  liveness  loudness  mode  speechiness  \
# 0   0.339             0.000    1    0.0812    -7.678     1       0.4090
# 1   0.557             0.000    8    0.2860    -7.259     1       0.4570
# 2   0.723             0.000    9    0.0824    -5.890     0       0.0454
# 3   0.579             0.912    5    0.0994   -12.118     0       0.0701
# 4   0.792             0.878    7    0.0332   -10.277     1       0.0661
#
#      tempo  time_signature  valence  popularity  duration
# 0  203.927               4    0.118          15     238.0
# 1  159.009               4    0.371           0     215.0
# 2  114.966               4    0.382          56     139.0
# 3  123.003               4    0.641           0     125.0
# 4  120.047               4    0.928           0     124.0

# %%
#top_spotify_songs = clean_spotify_df.sort_values(by=['popularity'], ascending=False, inplace=False)
#top_spotify_songs.head(10)

# %%
top_3000 = clean_spotify_df.sample(n=5000)
top_3000_df = pd.DataFrame(top_3000)
top_3000_df.count()
# Out:
# artist_name         5000
# track_id            5000
# track_name          5000
# acousticness        5000
# danceability        5000
# energy              5000
# instrumentalness    5000
# key                 5000
# liveness            5000
# loudness            5000
# mode                5000
# speechiness         5000
# tempo               5000
# time_signature      5000
# valence             5000
# popularity          5000
# duration            5000
# dtype: int64

# %%
top_3000_df.sample(20)
# Out:
#                     artist_name                track_id  \
# 107750  Wolfgang Amadeus Mozart  4nNRMKB3fj2KZ5a2kqdoVv
# 17934              SVDDEN DEATH  4L6i1rxmxVKwEPYpQl5jZN
# 115482                 Rita Ora  6k3WSp6MIic0wBk9uVjIXk
# 10530                  JT Music  4Of0QT1aNT12E1hSrUTocu
# 8254                LeAnn Rimes  7BMkBfNSSPpRhK1CjuhJhc
# 101804     Florida Georgia Line  0RO3tjH2cfyoGHLynijFcc
# 52288                  Conjurer  55BKGHohMqS3u1JuWg2O0n
# 51638              no sentences  6dX8Ig6x1O7dhv7aNvfRzz
# 102704    Johann Sebastian Bach  3M3ahhlvxyStgK3N0BqRiY
# 89888                  Toonorth  7eJACPIbYcYsxqJMtqTkYQ
# 28414           Sou El Flotador  78pzcKUAQbvXjDvwN36xYC
# 60145      José Alfredo Jimenez  2ZPzr2SgHkkoTalhQXyuUZ
# 27290                  Ethereal  6igzEWYuAhsxzAg4DxtRCr
# 46988          Loriela Ter-Veen  3MLNUyyIKvXwvYxn3BKhq1
# 70607            Tickle Torture  3JwZus0n5EHDw9Bf3MObWX
# 9308                      Marlo  7eisQ2yB1TNdIgaFe7YyHT
# 103536    Johann Sebastian Bach  1A3B9eQur63oGSrf289DG3
# 40624         Alfredo Rodriguez  4BdCMtsk40t1ICx5Vgpqv3
# 54681                    John B  2IO7NQ8fZnmydozfExHSHO
# 44929             The Griswolds  1rhEOqucBhAxinbc677Jnz
#
#                                                track_name  acousticness  \
# 107750  Così fan tutte, K. 588, Act I: E voi ridete? (...      0.995000
# 17934                                               BZZRK      0.097300
# 115482                         Let You Love Me - Acoustic      0.427000
# 10530                              Shepherd of This Flock      0.067900
# 8254                         One Way Ticket (Re-Imagined)      0.819000
# 101804                                              Women      0.425000
# 52288                                               Retch      0.000007
# 51638                                   Forest Mill Trail      0.237000
# 102704  Partita in B Minor (French Ouverture), BWV 831...      0.890000
# 89888                                           Querencia      0.260000
# 28414                                           Maniatica      0.116000
# 60145                                              El Rey      0.583000
# 27290                                                Bomb      0.760000
# 46988                                      Amor en Sonora      0.001780
# 70607             No One Feels for Your Love (Album Edit)      0.018200
# 9308                          A Beautiful Place Is Coming      0.001150
# 103536  The Well-Tempered Clavier, Book 2, Prelude & F...      0.994000
# 40624                                    The Little Dream      0.763000
# 54681                                         Unshakeable      0.025400
# 44929                           Out of My Head (Acoustic)      0.665000
#
#         danceability  energy  instrumentalness  key  liveness  loudness  mode  \
# 107750         0.384   0.277          0.000620    7    0.7350   -18.845     1
# 17934          0.585   0.876          0.108000   10    0.1050    -1.613     0
# 115482         0.521   0.413          0.000000    8    0.0895    -5.510     1
# 10530          0.845   0.714          0.000000   11    0.0827    -4.992     1
# 8254           0.714   0.206          0.000001   11    0.1120   -10.729     1
# 101804         0.368   0.592          0.000000    6    0.0849    -4.317     1
# 52288          0.262   0.951          0.678000    5    0.0391    -4.203     1
# 51638          0.854   0.219          0.960000    2    0.1050   -14.962     1
# 102704         0.517   0.268          0.098200   10    0.1050   -17.027     0
# 89888          0.605   0.244          0.876000    5    0.1260   -14.020     0
# 28414          0.662   0.745          0.000000    7    0.1800    -5.150     1
# 60145          0.343   0.374          0.000000    9    0.2340    -7.636     1
# 27290          0.850   0.552          0.000000    2    0.4820    -4.658     1
# 46988          0.471   0.807          0.000015    0    0.1190    -6.361     1
# 70607          0.784   0.828          0.050700    7    0.1020    -5.649     0
# 9308           0.818   0.492          0.959000    9    0.0648   -11.513     1
# 103536         0.290   0.223          0.856000    3    0.1050   -24.414     0
# 40624          0.423   0.420          0.591000    0    0.1000   -14.004     1
# 54681          0.494   0.917          0.372000    5    0.1710    -5.027     0
# 44929          0.678   0.236          0.000000    8    0.0728    -8.149     1
#
#         speechiness    tempo  time_signature  valence  popularity  duration
# 107750       0.0678  180.303               3   0.8190           4      83.0
# 17934        0.2790  146.755               4   0.4950          38     242.0
# 115482       0.0895  102.070               4   0.5760          58     189.0
# 10530        0.2020  124.989               4   0.5980          37     267.0
# 8254         0.0321   99.124               4   0.2630          24     257.0
# 101804       0.0385  117.988               3   0.4510          70     212.0
# 52288        0.1160   98.221               4   0.1860          33     194.0
# 51638        0.0867  131.985               4   0.0683          44     109.0
# 102704       0.0321   67.789               4   0.7360          13     176.0
# 89888        0.0286   92.984               4   0.0685          14     173.0
# 28414        0.0777  133.970               4   0.4640           0     225.0
# 60145        0.0351   73.411               4   0.8130          17     131.0
# 27290        0.1750  125.986               4   0.2870          29     259.0
# 46988        0.0541  181.938               4   0.7950          48     183.0
# 70607        0.0474  124.999               4   0.6810          16     460.0
# 9308         0.3180  139.918               4   0.5160          21      64.0
# 103536       0.0347   99.566               4   0.7620           5     249.0
# 40624        0.0338  119.906               4   0.5510          23     295.0
# 54681        0.0428  173.966               4   0.2550           9     345.0
# 44929        0.0311   94.065               4   0.3230          16     212.0

# %%
top_3000.to_csv("top5000_cleaned.csv", index=False)
